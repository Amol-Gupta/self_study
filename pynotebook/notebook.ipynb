# %% [markdown]
# ## Gaussian noise

# %%
# %matplotlib ipympl
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
n=1000
t= range(n)
y = np.random.normal(0,1,n)
plt.figure()
plt.plot(t,y)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Gaussian Random walk

# %%
n=500
m=7
t = range(n)

d_y = np.random.normal(0.05,0.3,(m,n))
y = np.cumsum(d_y, axis=1) +100 #cumsum is a numpy function that computes the cumulative sum of the elements of an array

plt.figure()
for c in range (m):
    plt.plot(t, y[c,:])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
n=500
m=7
t = range(n)

d_y = np.random.normal(0.01,0.3,(m,n))
y = np.cumsum(d_y, axis=1) +100 # cumsum is a numpy function that computes the cumulative sum of the elements of an array

plt.figure()
for c in range (m):
    plt.plot(t, y[c,:])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## OU process

# %%
# OU process simulation


# Parameters for the OU process
theta = 0.7      # Speed of mean reversion
mu = 0.0         # Long-term mean
sigma = 0.3      # Volatility
X0 = 1.0         # Initial value
T = 30.0         # Total time
dt = 0.01        # Time step
N = int(T / dt)  # Number of time steps

# Pre-allocate array for efficiency
X = np.zeros(N)
X[0] = X0

plt.figure()
# Generate the OU process
for t in range(1, N):
    dW = np.sqrt(dt) * np.random.normal(0, 1)
    X[t] = X[t-1] + theta * (mu - X[t-1]) * dt + sigma * dW

# Plot the result
plt.plot(np.linspace(0, T, N), X)
plt.title("Ornstein-Uhlenbeck Process Simulation")
plt.xlabel("Time")
plt.ylabel("X(t)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Simulation of 2 asset with different risk

# %%
n=2000
m=1
t = range(n)

for x in range(1, 4):
    d_y1 = np.random.normal(0.05,0.1,(m,n))
    d_y2 = np.random.normal(0.05,0.2,(m,n))
    d_y3 = np.random.normal(0.05,0.4,(m,n))
    d_y = np.vstack([d_y1, d_y2, d_y3])
    y = np.cumsum(d_y, axis=1) +100 #cumsum is a numpy function that computes the cumulative sum of the elements of an array

    plt.figure()
    for c in range (3):
        plt.plot(t, y[c,:])
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
